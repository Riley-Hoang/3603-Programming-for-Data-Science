# %% [markdown]
# <a href="https://colab.research.google.com/github/Riley-Hoang/3603-Programming-for-Data-Science/blob/main/Assignments/01-Getting_Started/NguyenNgocHoang_Week1_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 01 - Colab Intro
#
# Welcome to your first notebook in Google Colab!

# %% [markdown]
# ## ✅ Learning Goals
# - Run cells in a notebook
# - Edit Markdown and code
# - Save a copy to your own Drive

# %%
# 👋 Try running this cell!
print('Hello, Data Science World!')
# Out:
# Hello, Data Science World!

# %% [markdown]
# ## ✏️ Your Turn
# Modify the code below to print your name.

# %%
print('Nguyen Ngoc Hoang')
# Out:
# Nguyen Ngoc Hoang

# %% [markdown]
# ## 💾 Save a Copy
# - Go to **File > Save a copy in Colabs**.
# - Make sure it changed on your github repo.
#
# Move it to your `completed` folder.
